# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_name = pd.read_csv("sampleA_200step-(6, 1, 0.1).csv")
len_episode = data_name["episode"].max()

# %%
import pandas as pd
df = pd.read_csv("sampleA_200step-(6, 1, 0.1).csv")
# df5 = pd.read_csv("sampleA-(5, 1, 0.1)_bt.csv")
import numpy as np
import matplotlib.pyplot as plt
data_x=np.arange(1,201)
plt.figure(figsize=(8,5))
plt.xlim(0,200)
a=0.8
# plt.xlabel('Episode')
# plt.ylabel('Maximum activity of dopamine cells')
# plt.fill_between(data_x,df5.groupby(['episode'])['DA56D'].max(), alpha=a,color='black',label='(3,4), Down')
# plt.fill_between(data_x,df.groupby(['episode'])['DA56D'].max(), alpha=a,color='pink',label='(3,4), Down')
# # plt.fill_between(data_x,df5.groupby(['episode'])['DA55R'].max(), alpha=a,color='black',label='(3,3), Right')
# plt.fill_between(data_x,df.groupby(['episode'])['DA55R'].max(), alpha=a,color='tomato',label='(3,3), Right')
# # plt.fill_between(data_x,df5.groupby(['episode'])['DA54R'].max(), alpha=a,color='black',label='(3,2), Right')
# plt.fill_between(data_x,df.groupby(['episode'])['DA54R'].max(), alpha=a,color='gold',label='(3,2), Right')
# # plt.fill_between(data_x,df5.groupby(['episode'])['DA53R'].max(), alpha=a,color='black',label='(3,1), Right')
# plt.fill_between(data_x,df.groupby(['episode'])['DA44D'].max(), alpha=a,color='mediumseagreen',label='(2,2), Down')
# plt.fill_between(data_x,df5.groupby(['episode'])['DA43D'].max(), alpha=a,color='black',label='(2,1), Down')
plt.fill_between(data_x,df.groupby(['episode'])['DA75U'].max(), alpha=a,color='#F6878C',label='(2,1), Right')
# plt.fill_between(data_x,df5.groupby(['episode'])['DA42R'].max(), alpha=a,color='black',label='(2,0), Right')
plt.fill_between(data_x,df.groupby(['episode'])['DA73R'].max(), alpha=a,color='#9698C8',label='(2,0), Right')
# plt.fill_between(data_x,df5.groupby(['episode'])['DA32D'].max(), alpha=a,color='black',label='(1,0), Down')
plt.fill_between(data_x,df.groupby(['episode'])['DA52D'].max(), alpha=a,color='#FDD79F',label='(1,0), Down')
# plt.fill_between(data_x,df5.groupby(['episode'])['DA22D'].max(), alpha=a,color='black',label='(0,0), Down')
plt.fill_between(data_x,df.groupby(['episode'])['DA22D'].max(), alpha=a,color='#48BB7E',label='(0,0), Down')
plt.ylim(0,0.35)
plt.savefig('DA_transition_overlap.svg')
# plt.legend()

# %% [markdown]
# #### DA activity for the action of moving upward

# %%
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10,10))
x = np.arange(1,len_episode+1)
a, n = 1, 1
c = 'black'

for i in range(2, 9):
    for j in range(2, 9):
        plt.subplot(7, 7, n)
        plt.scatter
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.xlim(0,200)
        plt.ylim(0,1.1)
        data_name.groupby(['episode'])[f"DA{i}{j}U"].max().plot(color=c)
        plt.fill_between(x, data_name.groupby(['episode'])[f"DA{i}{j}U"].max(), alpha=a,color=c)
        n += 1
        
plt.savefig('DA_transition_on_maze_u.svg')

# %% [markdown]
# #### 左

# %%
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10, 10))
x = np.arange(1, len_episode+1)
a, n = 1, 1
c='black'

for i in range(2, 9):
    for j in range(2, 9):
        plt.subplot(7, 7, n)
        plt.scatter
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.xlim(0,200)
        plt.ylim(0, 1.1)
        data_name.groupby(['episode'])[f"DA{i}{j}L"].max().plot(color=c)
        plt.fill_between(x, data_name.groupby(['episode'])[f"DA{i}{j}L"].max(), alpha=a,color=c)
        n += 1
        
plt.savefig('DA_transition_on_maze_l.svg')

# %% [markdown]
# #### DA activity for the action of moving right

# %%
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10, 10))
data_x=np.arange(1,len_episode+1)
a, n = 1, 1
c = 'black'

for i in range(2, 9):
    for j in range(2, 9):
        plt.subplot(7, 7, n)
        plt.scatter
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.xlim(0,200)
        plt.ylim(0, 1.1)
        data_name.groupby(['episode'])[f"DA{i}{j}R"].max().plot(color=c)
        plt.fill_between(x, data_name.groupby(['episode'])[f"DA{i}{j}R"].max(), alpha=a,color=c)
        n += 1
        
plt.savefig('DA_transition_on_maze_r.svg')

# %% [markdown]
# #### DA activity for the action of moving downward

# %%
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10, 10))
data_x=np.arange(1,len_episode+1)
a, n = 1, 1
c='black'

for i in range(2, 9):
    for j in range(2, 9):
        plt.subplot(7, 7, n)
        plt.scatter
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.xlim(0,200)
        plt.ylim(0, 1.1)
        data_name.groupby(['episode'])[f"DA{i}{j}D"].max().plot(color=c)
        plt.fill_between(x, data_name.groupby(['episode'])[f"DA{i}{j}D"].max(), alpha=a,color=c)
        n += 1
        
plt.savefig('DA_transition_on_maze_d.svg')

# %% [markdown]
# #### DA activity for all the action

# %%
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10, 10))
x = np.arange(1, len_episode+1)
a, n = 1, 1
c='black'

for i in range(2, 9):
    for j in range(2, 9):
        plt.subplot(7, 7,n)
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.xlim(0,200)
        plt.ylim(0,1.1)
        plt.fill_between(x,data_name.groupby(['episode'])[f'DA{i}{j}U'].max(), alpha=a,color=c)
        plt.fill_between(x,data_name.groupby(['episode'])[f'DA{i}{j}R'].max(), alpha=a,color=c)
        plt.fill_between(x,data_name.groupby(['episode'])[f'DA{i}{j}L'].max(), alpha=a,color=c)
        plt.fill_between(x,data_name.groupby(['episode'])[f'DA{i}{j}D'].max(), alpha=a,color=c)
        n+=1
        
plt.savefig('DA_transition_on_maze_all.svg')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8,5))
data_x=np.arange(1,201)
plt.ylabel('Maximum activity')
plt.fill_between(data_x,df.groupby(['episode'])['DA56D'].max(), alpha=0.7,color='gold')
df.groupby(['episode'])['DA56D'].max().plot(color='gold',label='Dopamin')
(1+(df.groupby(['episode'])['gl_hyper66D'].max()-df.groupby(['episode'])['gl_gpe66D'].min()-1.1)).plot(color='tomato',label='Reward + HyperDirect(Global) + Indirect(Global)')
(-df.groupby(['episode'])['strio56D'].min()).plot(color='cornflowerblue',label='HyperDirect - Direct + Indirect')
plt.xlabel('Episode')
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("sampleA-(1, 1, 0.1).csv")

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15,8))
data_x = np.arange(1,201)
data_x = np.arange(1,201)
plt.rcParams["font.size"] = 15


str_da = '73R'
str_gl = '74R'
plt.ylabel('Maximum activity')
plt.fill_between(data_x,df.groupby(['episode'])['DA'+str_da].max(),color='#FDD79F')
df1 = (df.groupby(['episode'])['strio'+str_gl].max()+5*(df.groupby(['episode'])['gl_hyper'+str_gl].max()-df.groupby(['episode'])['gl_gpe'+str_gl].min()-1.1))
df2 = (-(-5*(df.groupby(['episode'])['gl_hyper'+str_gl].max()-df.groupby(['episode'])['gl_gpe'+str_gl].min()-1.1)))
df1.replace(-5.5, 0, inplace=True)
df2.replace(-5.5, 0, inplace=True)
df1.plot(color='#F6878C',label='Reward + HyperDirect(Global) + Indirect(Global)')
df2.plot(color='#9698C8',label='HyperDirect - Direct + Indirect')
plt.xlabel('Episode')
plt.xlim(0,200)
plt.ylim(0,0.8)
# plt.savefig('gl-lc=DA.svg')
# plt.legend()

# %%
import seaborn as sns

df0 = pd.read_csv('sampleA-(0, 1, 0.5).csv')
dfh = df0.groupby(['episode'])['H'].max()
dfd1 = df0.groupby(['episode'])['D1'].min()
dfd2 = df0.groupby(['episode'])['D2'].max()
df = pd.merge(pd.DataFrame(dfh), pd.DataFrame(dfd1), on='episode')
df = pd.merge(pd.DataFrame(df), pd.DataFrame(dfd2), on='episode')
sns.stripplot(data=df)
plt.show()
